# %%
from SystemComponents.cell import Cell

from BoundaryConditions.Simulation.SimulationData import getSimData
from Simulation.executeModel import simulate

from matplotlib import pyplot as plt

# %%
import os

os.chdir("d:/ensysim")

# %%
# parameter
Eg = 1060
ToutN = -13.8

startDate = "01.01.2020"
endDate = "01.01.2021"

# %%
nSteps, time, SLP_PHH, SLP_BSLa, SLP_BSLc, HWP = getSimData(startDate, endDate)

# %%
c1 = Cell(10, Eg, ToutN, hist=nSteps)

# %%
simulate(c1, nSteps, SLP_PHH, SLP_BSLa, SLP_BSLc, HWP)

# %%
c1.balance_e
# Out:
# array([ -894.7569 , -1112.3394 ,  -998.79865, ..., -1472.1271 ,
#        -1325.1548 , -1350.4615 ], dtype=float32)

# %%
plt.plot(time, c1.balance_e.cumsum() * 0.25)
